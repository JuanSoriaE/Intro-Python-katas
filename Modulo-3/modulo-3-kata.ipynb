# %%
asteriodVel = 49

if asteriodVel > 25:
    print('Asteriod comming to the earth!')

# %%
asteriodVel = 19

if asteriodVel >= 20:
    print('Go out and see the ligth ray!')

# %%
asteriodVel = 20
asteriodSize = 20

if (asteriodSize > 25 and asteriodSize < 1000) or asteriodVel > 25:
    print('Danger!')
elif asteriodVel >= 20:
    print('Go out and see the light ray!')
