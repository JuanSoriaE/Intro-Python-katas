# %%
distance1 = 149597870
distance2 = 778547200

# %%
distance = distance2 - distance1
distanceMiles = round(distance*0.621)

print(distance, distanceMiles)

# %%
distance1 = int(input('Type the first distance: '))
distance2 = int(input('Type the second distance: '))

distance = abs(distance2 - distance1)
distanceMiles = round(distance*0.621)

print(distance, distanceMiles)
