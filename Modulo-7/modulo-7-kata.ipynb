# %%
newPlanet = ''
planets = []

while newPlanet.lower() != 'done':
    newPlanet = input('Type the new planet: ')
    if newPlanet.lower() != 'done':
        planets.append(newPlanet)

# %%
for planet in planets:
    print(planet)
